# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
input_keyword = "比特幣"  # 這裡可以自己定義有興趣的關鍵字

utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果

# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = '/wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# 比特幣: %E6%AF%94%E7%89%B9%E5%B9%A3
# /wiki/%E6%AF%94%E7%89%B9%E5%B9%A3

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')

#
# 解析回傳資料，並萃取文章內容
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# BTC[註 1]、XBT[1][註 2]、₿、฿[2][註 3]
#
# 比特幣（英語：Bitcoin[註 4]，縮寫：BTC 或 XBT）是一種基於去中心化，採用點對點網路與共識主動性，開放原始碼，以區塊鏈作為底層技術的加密貨幣[6]，比特幣由中本聰（網名）[註 5]（Satoshi Nakamoto）於2008年10月31日發表論文[7]，2009年1月3日，創世區塊誕生。在某些國家、央行、政府機關則將比特幣視為虛擬商品，而不認為是貨幣[8]。
#
# 任何人皆可參與比特幣活動，可以通過稱為挖礦的電腦運算來發行。比特幣協定數量上限為2100萬個，以避免通貨膨脹問題。使用比特幣是透過私鑰作為數位簽章，允許個人直接支付給他人，與現金相同，不需經過如銀行、清算中心、證券商、電子支付平台等第三方機構，從而避免了高手續費、繁瑣流程以及受監管性的問題，任何用戶只要擁有可連線網際網路的數位裝置皆可使用。
#
# 但是由於比特幣區塊鏈在一定時間內能接受的交易量有限，約每10分鐘能接受最多2,500筆交易，交易手續費也會隨著比特幣交易量而波動，在2017年6月，小於1毫比特的交易，交易手續費已遠遠大於交易金額[9]；在2017年12月，Steam宣布停止接受比特幣，理由是「交易費用高昂，且波動性大」，在2018年2月，平均交易手續費從2017年第四季度的34美元，下降至約1美元[10]，而此問題，正在試圖以閃電網路之類的技術來解決，擴充比特幣一定時間內的交易量。
#
# 有觀點認為，比特幣的問世是人們憎恨商品經濟中國家主權貨幣超發、以及貨幣政策干預[11]、嚮往禮物經濟中社區共識貨幣自主的結果[12]；比特幣的匯率是全球投資者增加或者減少的反應[13]；而比特幣的底層技術區塊鏈可應用在各行各業[14]。
#
# 通常，首字母大寫的「Bitcoin」是指其所使用的比特幣技術與網路，而首字母小寫的「bitcoin」才是指貨幣本身[15]。比特幣也是區塊鏈支付系統和虛擬計價工具[16]，由於其採用密碼技術來控制貨幣的生產和轉移，而沒有中央的發行機構，無法任意增發，交易在全球網路中執行，有特殊的隱秘性，加上不必經過第三方金融機構，因此得到越來越廣泛的應用，也成了非法交易的媒介。使用者利用個人電腦和智慧型手機中的加密錢包軟體，無需任何銀行、信用卡、線上支付公司等中介機構，可隨時隨地在網路上直接交換物品、服務。 [17][18][19][20][21][22][23]根據劍橋大學2017年的研究，全球有多達580萬個加密錢包活躍用戶，其中大多數使用比特幣。[24]同時，有觀點認為，比特幣技術得到了廣泛的認可和使用，使人類迎來了區塊鏈時代。[25][26]
#
# 作為記帳系統，比特幣不依賴中央機構發行新錢、維護交易，而是由區塊鏈完成，用數位加密演算法、全網抵禦51%算力攻擊保證資產與交易的安全。交易記錄以被全體網路電腦收錄維護，每筆交易的有效性都必須經過區塊鏈檢驗確認。[27]
#
# 作為記帳單位，比特幣的最小單位是 0.00000001 （一億分之一）比特幣，稱為「1聰」。如有必要，也可以修改協定將其分割為更小的單位，以保證其流通方便，區塊回報每產出21萬個區塊減半一次，大約4年，最近一次減半在2016年7月9日，而此種收斂等比數列的和必然是有限的，到2140年時，將不再有新的比特幣產生，最終流通中的比特幣將總是略低於2100萬個[28]。2019年5月12日時，比特幣總存量約17,695,512個，實際可流通的量還會因為私鑰遺失等因素更加減少。
#
# 區塊鏈（Blockchain）是比特幣的一個重要概念，該概念在中本聰的白皮書中提出，區塊鏈是一串使用密碼學方法相關聯產生的資料塊（稱為「區塊」，block）。新增的資料塊總能連結到上一個區塊，即整條區塊鏈的尾部。比特幣對等網路將所有的交易歷史都儲存在「區塊鏈」（blockchain）中，所以區塊鏈可以看作記錄著比特幣交易的帳本。區塊鏈是一群分散的用戶端節點，並由所有參與者組成的分散式資料庫，是對所有比特幣交易歷史的記錄[29]。中本聰預計，當資料量增大之後，使用者端希望這些資料並不全部儲存自己的節點中。為了實現這一目標，他採用引入雜湊函式機制。這樣用戶端將能夠自動剔除掉那些自己永遠用不到的部分，比方說極為早期的一些比特幣交易記錄。中本聰創造了比特幣系統的第一個區塊，即「創世區塊」，並附有一句「The Times 03/Jan/2009 Chancellor on brink of second bailout for banks」，而這句是當天泰晤士報的頭版文章標題。
#
# 確認一項交易的過程，是由解決一系列計算難題的工作量證明機制來實現的。工作量證明機制要求電腦的計算能力為某個有限值的情況下，需要運算一定的時間才能解決，這就使得攻擊者無法重寫、修改交易歷史，除非他能夠擁有相對比特幣對等網路系統更強大的計算能力，從而能以更快的速度產生區塊鏈（稱為"51%攻擊"[30]）。工作量證明機制的難度由系統自動調節，所以新區塊的生成平均需時10分鐘。整個比特幣對等網路的節點都會自動檢測交易和區塊的有效性，並忽略任何違背規則的交易和區塊，比如那些產生錯誤數量的區塊，或多次發送同一份額比特幣的交易行為。
#
# 參與處理區塊的用戶端可以得到一定量新發行的比特幣，以及相關的交易手續費。為了得到這些新產生的比特幣，參與處理區塊的使用者端需要付出大量的時間和計算力（為此社會有專業挖礦機替代電腦等其他低配的網路裝置），這個過程非常類似於開採礦業資源，因此中本聰將資料處理者命名為「礦工」，將資料處理活動稱之為「挖礦」。這些新產生出來的比特幣可以報償系統中的資料處理者，他們的計算工作為比特幣對等網路的正常運作提供保障。
# 有鑑於此，其他類似競爭幣（Altcoin）都是用了相同的理念去處理端間交易資料，只是在工作量證明機制上進行調整，如採用權益證明（Proof of Stake）[31]和Scrypt演算法等。[32]
#
# 「比特幣讓人們第一次可以在網路上交易身家財產，而且是安全的，沒有人可以挑戰其合法性。」
#
# [33]
#
# 比特幣錢包使使用者可以檢查、儲存、花費其持有的比特幣，其形式多種多樣，功能可繁可簡，它可以是遵守比特幣協定運行的各種工具，如電腦用戶端、手機用戶端、網站服務、專用裝置，也可以只是儲存著比特幣私密金鑰的介質，如一張紙、一段暗號、一個快閃隨身碟、一個文字文件，因為只要掌握比特幣的私密金鑰，就可以處置其對應位址中包含的比特幣。比特幣無法存入一般的銀行帳戶，交易只能在比特幣網路上進行，使用前需下載客戶端或接入線上網路[34]。
#
# 比特幣客戶端有很多，下文舉幾例列出。
#
# 比特幣最初客戶端為Bitcoin QT，由中本聰開發[34]。Bitcoin QT從0.4.0版本開始，支援錢包檔加密儲存。加密的錢包在每次付款的時候，都必須輸入密碼。但如果用加密之前備份的錢包檔案（wallet.dat）替換回來，還是可以正常交易。考慮到比特幣的原理可得出，掌握私密金鑰即擁有對相應位址中比特幣的處置權，不管對錢包檔案（內容包括各個位址對應的私密金鑰）是進行了加密還是刪除，都不能否定它。
#
# 其他客戶端都是以Bitcoin QT為原型開發的。通常支援雲儲存區塊，以避免使用者花費大量時間和磁碟空間下載舊交易資訊。並且各自提供進階功能。如Armory、Electrum和MultiBit等。此三者特點如下：[34]
#
# 比特幣也有運行在智慧型手機上的用戶端。
#
# 硬體錢包是專門處理比特幣的智慧型裝置，例如只安裝了比特幣用戶端與聯網功能的樹莓派。硬體錢包通常可以提供更多的安全保障措施。
#
# 線上錢包服務可以讓用戶在任何瀏覽器和行動裝置上使用比特幣，通常它還提供一些額外功能，使用戶對使用比特幣時更加方便。但選擇線上錢包服務時必須慎重，因為其安全性受到服務商的影響。
#
# 線上錢包服務有「區塊鏈上」（on-chain）與「區塊鏈外」（off-chain）的區別：鏈上錢包服務商幫助用戶保管加密後的私密金鑰，用戶的比特幣餘額可以在區塊鏈上查詢到，類似為每位用戶準備一個獨立的保險箱；鏈外錢包服務商幫助用戶保管比特幣本身，相當於把用戶資金放在自己的金庫中，給用戶提供存款證明。
#
# 比特幣最需要保護的核心部分是私密金鑰（私鑰），因為用戶是以私鑰來證明所有權，並以此使用比特幣，儲存私密金鑰的介質也可以稱為錢包，當錢包遺失、損毀時，為比特幣丟失，離線錢包可以是紙錢包、腦錢包、冷錢包、輕量錢包。
#
# 比特幣在產生位址時，相對應的私密金鑰也會一起產生，彼此的關係猶如銀行存款的帳號和密碼，有些線上錢包的私密金鑰是儲存在雲端的，使用者只能透過該線上錢包的服務使用比特幣。
#
# 位址用於接收比特幣，功能類似銀行的存款帳號，但不需要實名登記。若只公開位址不必擔心裡面的比特幣被盜走，也沒有任何個人資料，也可以離線產生。比特幣的位址是由使用者的公開金鑰經過 SHA-256 雜湊運算後，再通過 RIPEMD-160 雜湊運算而得，其長度固定為 160 個位元（bits），通常會利用 Base58 將之編碼成一串由英文字母和數字所組成的字串，以方便顯示或散布，其特徵是皆以「1」或者「3」開頭，區分大小寫[36]，但不包括「IlO0」等字元，「1」開頭的位址長26~34位元，「3」開頭的位址長34位元，例如"1DwunA9otZZQyhkVvkLJ8DV1tuSwMF7r3v"，位址也可編碼成快速反應矩陣碼(QR-Code)的形式讓行動裝置能夠便捷地讀取複製 。比特幣用戶端可以離線生成比特幣位址[3] 。一個人可以生成並擁有許多比特幣位址，並用在不同的交易上，而且除非自己揭露，或與其他資料連結，否則外人無法看出其中的關聯。可用的比特幣位址數量接近2161個[來源請求]。形象地說，假如地球上約有263粒沙，[37]如果每一粒沙中有一個地球，那麼比特幣位址總數遠遠超過所有這些「地球」上的所有的沙子的數量。
#
# 比特幣的私密金鑰（私鑰，private key），作用相當於金融卡提款或消費的密碼，用於證明比特幣的所有權。擁有者必須私密金鑰可以給交易訊息（最常見的，花費比特幣的訊息）簽名，以證明訊息的發布者是相應位址的所有者，沒有私鑰，就不能給訊息簽名，作為不記名貨幣，網路上無法認得所有權的證據，也就不能使用比特幣，交易時以網路會以公鑰確認，掌握私密金鑰就等於掌握其對應位址中存放的比特幣。
#
# 私密金鑰必須保密、否則任何人只要擁有某一位址的私密金鑰，即可使用其中的比特幣。也不能遺失，而且不像金融卡密碼遺忘時，用戶可以根據當地的金融規範，攜帶自己的身分證件，親自前往金融機構據點，辦理密碼重設後繼續使用原來的帳戶，但若比特幣的私鑰遺失，將如同忘記保險箱的密碼而無法正常打開取用保險箱內的物品，而且沒有方法可以重設（除非有事先備份），2013年，有一位英國使用者因為不小心丟棄了存有其私密金鑰的硬碟，導致裡面的7,500個比特幣，當時價值750萬美元，無法使用。[38]，除非私鑰被找到，否則這些比特幣將永「躺」在區塊鏈裡，不再流通，而使得流通中的比特幣變少。[39]，而要破解私鑰的難度很高，這是其中一個作為不記名的比特幣的主要安全機制。根據區塊鏈業者Chainalysis的估算，在2017年底時，約有17%至23%，278萬個到379萬個的比特幣因為私鑰遺失、密碼遺忘等原因，而永遠無法使用與進入流通。
#
# 比特幣私密金鑰通常由51位元或52位元字元表示，其編碼方式與比特幣位址相似。51位元標記法由數字「5」開頭，52位標記法由「K」或「L」開頭。比特幣位址是由比特幣公開金鑰進行雜湊運算得出的，公開金鑰是可以通過私密金鑰推算出的。所以掌握私密金鑰就可以推算出私密金鑰對應的位址（不可逆），這相當於只需要輸入一組正確的密碼，就可以推算出帳戶名稱並登入，而無法從帳戶名稱反向推算出密碼般。
#
# 2013年聖誕節前，12天比特幣節目中，Adam Johnson收到Bloomberg電視台的主播Matt Miller送的價值20美元的比特幣禮物卡。他開心的打開禮物卡包裝，在攝影機前展示了約10秒鐘禮物卡，然後，10秒鐘之內，錢就不見了。這張禮物卡上面，是一個比特幣錢包的位址跟私鑰的QR CODE。[40]
#
# 只要能連上網路，和有適當的中央處理器CPU、圖形處理器GPU、特殊應用積體電路ASIC等電腦裝置，稱為「礦機」，任何人都可挖礦。為了獲得系統每十分鐘獎勵的比特幣，找到讓帳冊區塊難以被惡意修改但是卻易於驗証的數學難題，此過程猶如開採礦物一樣困難，故稱為「挖礦」，使用礦機挖礦的人被稱為「礦工」。挖礦還包含打包和驗証數千筆交易成為區塊，證明轉帳者有足夠的比特幣，防止一幣多付的發生，從而賺取比特幣手續費。[41][42]
#
# 目前因為區塊容量上限 1MB 以及近期比特幣交易量大增的因素，造成等候確認時間大增，手續費也大幅增加[43]，計畫在2017年8月1日開始，實施Segwit2x，即隔離見證加區塊大小提升至2MB（2,097,152位元組），以實行擴容，增加比特幣交易容量。[44]另有比特幣無限，主張不限制區塊容量。
#
# 有一個分叉，名為比特幣現金（Bitcoin Cash，BCH）已在2017年8月1日出現，而分叉後第一個開始區塊478559，而BCH 478559的區塊大小約1.9MB，超過原有區塊容量上限，意味著比特幣現金的正式誕生[45]，所有在分叉前的比特幣持有者將自動擁有同金額的"比特幣現金"區塊鏈，區塊容量上限立即提升至8MB[46][47]
#
# 然而，比特幣現金的誕生也伴隨著不少爭議。比如，其最初使用的交易代碼並不是"BCH"，而是"BCC"[48]，這正好與另一個加密貨幣Bitconnect衝突，而且和Bitfinex上代表"Bitcoin Core"的鏈分叉期貨(Chain Split Token)交易代碼也是雷同的[49]，這曾經讓部分投資者感到混淆。
#
# 而且，BCH開發者修改了比特幣原有的難度調整演算法，引入了"緊急難度調整"(EDA)機制，可以讓BCH的挖礦難度在出塊較慢的情況下單向劇烈下降，以此從競爭對手BTC鏈吸引礦工。這種手段被認為可以起到"維持BCH鏈自身運轉不停擺"[50]的作用，但同時也引發了算力在BTC和BCH兩條鏈間大幅遷移"震盪"的現象，導致BCH和BTC都不時發生不同程度的交易確認時間延長問題；而且EDA加速了BCH的新幣產生速度，可能導致BCH下一次產量減半提早到來。後來BCH開發者修改了代碼，通過一次硬分叉升級將EDA廢除，以新的難度調整演算法取而代之，消除了EDA存在的難度單向劇烈下調、回饋不夠及時等問題[51]，在BCH經過本次硬分叉升級後，算力在BCH和BTC兩條鏈間震盪的不良現象也隨之改善、消失。
#
# 有人認為目前只有相容Bitcoin Core客戶端的鏈(即BTC)才是真正的比特幣，他們往往會把比特幣現金叫做"Bcash"[52]；同時也有人認為比特幣現金才是真正的比特幣[53]，而且認為"Bcash"這種稱呼實質上是一種針對比特幣現金的社會工程學攻擊手段。[54]
#
# 比特幣早期布道者Andreas M. Antonopoulos則認為基於比特幣的去中心化本質，並不存在一個"真正的比特幣"標準答案，每一個人都應該有自己的獨立認知。[55]
#
# 比特幣黃金（Bitcoin Gold，BTG）是2017年10月25日的再次分叉，比特幣持有人將生成出等量的比特幣黃金幣，主要是希望解決日漸中心化的挖礦現象，比特幣黃金將採用新的雜湊演算法Equihash，來防止 ASICs 挖礦。[56][57]同時，Bitcoin Gold開發也預挖了一部分BTG，作為對團隊維持開發工作的支援和激勵。[58]
#
# 原定在區塊494,784（2017年11月）進行的SegWit2x硬分叉已被取消，後續又有數十個比特幣分叉，包括Bitcoin Diamond、Super Bitcoin等[59][60]。此類分叉的湧現甚至引出了一個新的概念"IFO"，即"首次分叉發行"(Initial Fork Offering)，與"ICO"(Initial Coin Offering，首次代幣發行)性質類似。
#
# 比特幣對等網路將所有的交易歷史都儲存在區塊鏈中，比特幣交易就是在區塊鏈帳本上「記帳」，通常它由比特幣用戶端協助完成。付款方需要以自己的私鑰對交易進行數位簽章，證明所有權並認可該次交易。比特幣會被記錄在收款方的位址上，交易無需收款方參與，收款方可以不線上，甚至不存在，交易的資金支付來源，也就是花費，稱為「輸入」，資金去向，也就是收入，稱為「輸出」。如有輸入，輸入必須大於等於輸出，輸入大於輸出的部分即為交易手續費。
#
# 礦工產出交易沒有輸入，只有輸出，交易記錄會顯示新生成的比特幣（Newly Generated Coins），除礦工產出交易外，一個輸入必然是另一筆交易的一個輸出，也就是一筆收入必然是其他人的支付。一個輸入沒有成為另一筆交易的輸出時，它是「未花費的」，也就是「帳戶餘額」。收錄此交易的區塊被廣播後，此交易就有了「1個確認」。礦工們平均每10分鐘產生一個區塊，每一個新區塊的誕生會使此交易的確認數加1。當確認數達到6時，通常這筆交易被認為比較安全、難以逆轉。[61]。比特幣交易為不可逆，每一筆交易都無法復原，商家不必遭到詐騙式的拒付而遭受損失，唯一可以獲得退款的方法，就是請對方再做一筆反向交易，但需要對方的配合。[62]
#
# 比特幣的所有交易都會被記錄在區塊鏈上，最富有的位址可以很輕易的在網路上公開查詢[63]，然而，作為匿名的比特幣位址，原則上無法得知持有者，除非特別情況，通常也無法得知某人擁有的比特幣位址，每個人都可以建立及擁有許多的比特幣位址，不同位址可能由同一人持有，包括有些餘額很少的位址，且不代表持有者的真實財富狀況，而該位址的私鑰若遺失，裡面的比特幣就不能使用，因此某些位址的比特幣，特別是只進不出、或長期未花用的位址，可能是私鑰已遺失、而任何人皆無法再使用的位址，而且有些位址是由交易所等機構持有，不屬於特定個人。
#
# 最富有的位址有大約10萬多個，大多是作為交易所的冷錢包[64][65][66]
#
# 有數個比特幣位置存有未使用的大量資金[67][68][69]。其中部分位址曾存有美國聯邦調查局自線上黑市「絲路」創辦人「恐怖海盜羅伯特」（Dread Pirate Roberts）處查扣的比特幣資金，這些位址已在2013年10月被美國司法部強制下線。[70]
#
# 比特幣結合P2P對等網路技術和密碼學原理，來維持發行系統的安全可靠性。[71]與有中心伺服器的中央網路系統不同，在P2P網路中無中心伺服器，每個用戶端既是一個節點，也有伺服器的功能，任何一個節點都無法直接找到其他節點，必須依靠其戶群進行資訊交流。比特幣使用以下3種機制，來解決初次執行時，尋找其他節點的問題。
#
# 現在不需要執行上述3個機制，一旦連接到比特幣的某個節點，在傳送的資訊中，就會包含對等網路P2P其他節點的位址，直接通過其匿名用戶群來找到其他節點。節點遍布整個網際網路的P2P技術和密碼學原理相結合，確保了比特幣發行系統無法被政府、組織、或駭客監控、隔離、或破壞，從而保障了系統的可靠性和匿名性。[72]。阻斷服務式（DDoS）以及其他攻擊，其目標都是針對比特幣交易中心，這和攻擊或關閉傳統貨幣交易所的網路，理論上不影響其貨幣發行和使用一樣。2013年5月，美國政府查封世界上最大的比特幣交易所銀行帳戶後，兌換率還是維持在1比特幣兌換120美元上下。[73]
#
# 匿名與隱私是比特幣問世時主要的訴求，因為交易或建立比特幣位址、錢包時，不需要提供任何個人資訊，但交易資訊是向全網廣播的，因此所有交易記錄細節都是公開的、而可以追蹤。不同於採用實名制的傳統金融機構，通過將交易資訊與客戶個資嚴格保密來保護客戶隱私，但若國家機關基於特定原因，而向金融機構調取資料，或是被駭客攻擊，這樣仍然會使隱私消失，而使得特定交易資訊與客戶個資曝光[74]，比特幣可通過為每筆交易建立不同的位址來保護隱私，bitcoin.org網站也建議每一個位址只做一次交易[75]。例如，甲方希望傳送1.20 BTC給乙方，那麼任何人都可以通過比特幣網路上所有節點都能夠查閱這筆1.20 BTC的交易細節。但除非甲方或者乙方公布自己擁有其中的一個位址，否則作為不記名的貨幣，其他人很難知道這筆交易是發生在甲方與乙方之間的。
#
# 理論上，如果有調查者能夠將某一個位址與某一用戶間建立關聯，那麼調查者就可以追根溯源，搞清楚每一筆交易的對方，如比對其它的個人資訊，如交易的IP位址等，某特定交易的資訊，要求已知的一方交代交易的另一方的身分等，並順藤摸瓜經由交易鏈，並配合比特幣交易所基於反洗錢法的KYC身分認證，直到確定目標位址的真實所有者，因此，只要有一筆交易被證明為犯罪，如某些交易是綁架的贖金或是未經持有人同意下，從被盜的帳戶轉帳出去等，之後所有後續轉出去的位址都會被"汙染"。但實際上，想要確定某個比特幣的真實所有者依然是異常困難的，加上後續混合比特幣(Bitcoin Mixing)、或洗錢服務的產生，雖然強化了隱私保護，但也增加金流追蹤的困難，這一屬性使得比特幣吸引了很多非法物品交易者的興趣。[76][77][78]
#
# 為求徹底解決比特幣有關隱私性、被監控、被追蹤等疑慮，後續開發了強調隱私，有自動混幣或加密功能的區塊鏈與替代加密貨幣，通稱隱私幣，包括達世幣、門羅幣、Zcash、PIVX等。[79]
#
# 網路安全公司趨勢科技提出資安警告，比特幣採礦惡意軟體猖獗，根據統計日本約3000台電腦感染了該病毒，約佔全球的四分之一、數量居首，該公司呼籲日本用戶不要瀏覽可疑郵件及網站。第二位是美國的2606台（占21%），其次為澳大利亞、印度、法國、與台灣。也稱台灣為全球第6大受害者，建議台灣使用者以個別管理錢包、離線管理降低被竊風險。
#
# 2010年6月，澳大利亞廣播公司發現一名雇員用公司的伺服器進行挖礦。[98]
#
# 2011年6月，網路安全公司賽門鐵克公司發出警告，殭屍網路正在參與到比特幣"挖礦"中。[99][100]這會占用受害者的電腦運算能力、消耗額外的電力並導致主機溫度升高。
#
# 在2011年8月，比特幣挖礦的殭屍網路被發現了。[101]同時也發現，木馬感染的「Mac OS X」電腦被用於比特幣挖礦。[102]
#
# 另外，一些有爭議軟體也大量利用顯示卡的平行計算能力生成殭屍網路，進行比特幣挖礦。[103]
#
# 2017年12月2日，阿根廷首都布宜諾斯艾利斯的一家星巴克咖啡館，被發現店內提供顧客使用的Wi-Fi遭植入Coinhive挖礦程式。[104]
#
# 比特幣基於不受政府控制、相對匿名、難以追蹤的特性，和其它貨幣一樣，也被用來進行非法交易，成為犯罪工具、或隱匿犯罪所得的工具。
#
# 比特幣曾經被指控為「龐氏騙局」，因為比特幣的匯率在不斷地上漲，而早期的比特幣用戶挖礦較為容易。[105][106]歐洲中央銀行曾對這一虛擬貨幣進行仔細認真的研究，在2012年發表的分析報告中表示以現有資料難以判斷比特幣是或不是龐氏騙局，一方面買入比特幣的人需要找到其他人願意買入方可取回資金，許多人認為這符合龐氏騙局的特徵，但另一方面比特幣計劃從來沒有向任何人承諾高回報，報告認為如果以金錢作考量，比特幣對於使用者而言是一個高風險系統。[107]
#
# 在美國，一個匿名化的交易絲綢之路所主導，自稱為黑市亞馬遜Amazon.com，比特幣是它的唯一交易貨幣。[113] 2011年，紐約州參議員查爾斯·舒默和其他人致信給美國藥品管理局，指責絲綢之路運用比特幣洗錢，要求對絲綢之路和比特幣展開調查。[113]和TOR一樣，比特幣都是合法技術，被用在絲綢之路的網站中，為執法部門帶來了很多難題。[114]不過，開發比特幣的核心成員Jeff Garzik表示，雖然各方的身分是匿名的，執法部門仍可以利用先進的網路分析技術，通過區塊鏈中公開的交易記錄流程來跟蹤單個比特幣使用者。[115] 2013年11月，絲綢之路已經被美國政府查封。
# 2014年1月，美國司法部宣布，比特幣交易站運營者羅伯特·法伊拉（Robert Faiella）和查理·史瑞姆被正式指控參與洗黑錢，幫助絲綢之路販毒者將100萬美元兌換成為比特幣。 [116]
#
# 由於和違法行為之間常有牽連，因此比特幣受到許多嚴厲的檢視。在2013年，美國聯邦調查局強制關閉線上黑市「絲路」，並查扣144,000比特幣，當時約值2,850萬美元[117]。但若與其他國家比較，美國政府對比特幣持相對友善的態度[118]。中國大陸政府的新規定限制了人民幣和比特幣之間的交易[119]。歐洲銀行業管理局則警告比特幣缺乏對消費者的保障[120]。比特幣可能遭竊且在技術上不可能獲得任何補償[121]。
#
# 比特幣也普遍被用來當成勒索軟體的金流工具，手法是駭入受害者的電腦後，將受害者的電腦的檔案加密，受害者在約72-96小時的時限內必須支付一定金額後，才能取得金鑰解密，否則逾時金鑰銷毀，受害者如要解開已被加密的檔案將非常困難，因此，不只個人[122]，學校[123]、證券商[124]、醫院[125]、寺廟[126]不等，而且還發展出以比特幣為報酬的駭客攻擊服務[127]
#
# 2017年5月，一款名為WannaCry的勒索軟體，造成數十萬台電腦遭到感染，也是以比特幣為支付工具。[128]
# 2017年6月，另一款名為Petya的勒索軟體，也是以比特幣為支付工具。[129]
#
# 2018年中，5個月內已有近三百種虛擬貨幣出現，當中它們亦流行以ICO募款。而最近四月發生的越南虛擬貨幣Pincoin於集資後籌募得六億六千萬美元後失蹤，亦引起市民的哄動及留意。而同年3月19日，香港證監會亦首次叫停在港集資的首次代幣發行計劃[130]。
#
# 比特幣仍然有合法或正當的用途。有多種途徑使用比特幣，通過電子貨幣交易所、比特幣提款機[131]、服務商和個人等管道，就能兌換為當地的現金或金幣或以現金或金幣購買比特幣；也可以直接使用它購買物品和服務，或使用比特幣金融卡。[132][133][134]特別繼維基解密宣布接受比特幣捐助後，認可使用比特幣的個人、組織和企業迅猛增長。[135][136][137] Coinmap是一個專門收錄全球範圍內接受比特幣支付的實體商家網站，比特幣維基有一個網頁則列出了接受比特幣支付的合法網路商家。[138]
# 隨著比特幣金融卡的啟用，即使商家不接受比特幣，仍然可以依照比特幣與法幣的即時匯率，而以比特幣付款，猶如刷新臺幣帳戶的金融卡支付外幣（美元、歐元等）消費，仍然可以依照該外幣與新臺幣的即時匯率，而從新臺幣的存款帳戶扣款來完成付款，這樣商家只要支援Visa 或 Mastercard等信用卡，或是Apple Pay等行動支付功能者皆能使用，[139][140][141]，使用範圍就能從直接接受比特幣的1萬商家，大幅擴大到包括網路購物、賣場購物、餐廳和咖啡廳用餐、搭乘交通工具、加油站加油等數千萬個商家（Visa 2,900萬、MasterCard 3,200萬個），如果許可，並可使用世界各地逾3千多萬台一般法幣ATM，以比特幣提領當地現金使用[142]。
#
# 比特幣做為一種非由國家力量發行及擔保的交易工具，已經被全球個人、組織、企業等廣泛認可、使用和參與。某些政府承認它是貨幣，但也有一些政府是當成虛擬商品，而不承認貨幣的屬性。
#
# 除了比特幣，目前還有許多相似的同類型貨幣，統稱為加密貨幣，比特幣以外的加密貨幣，又稱為山寨幣、競爭幣（英語：altcoin），目前有數千種以上的加密貨幣在流通，並且持續增加中，新的加密貨幣可能在任何時間被任何人建立出來，可經由獨立建立、硬分叉、透過ICO發行的代幣等方式建立。其它加密貨幣有更多的功能、更完善的隱私保護、更快的區塊生成時間、支援智慧型合約等。

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))
# Out:
# 外部連結: [點對點] /wiki/%E9%BB%9E%E5%B0%8D%E9%BB%9E
# 外部連結: [共識主動性] /wiki/%E5%85%B1%E8%AF%86%E4%B8%BB%E5%8A%A8%E6%80%A7
# 外部連結: [開放原始碼] /wiki/%E9%96%8B%E6%94%BE%E5%8E%9F%E5%A7%8B%E7%A2%BC
# 外部連結: [區塊鏈] /wiki/%E5%8C%BA%E5%9D%97%E9%93%BE
# 外部連結: [加密貨幣] /wiki/%E5%8A%A0%E5%AF%86%E8%B2%A8%E5%B9%A3
# 外部連結: [中本聰] /wiki/%E4%B8%AD%E6%9C%AC%E8%81%AA
# 外部連結: [央行] /wiki/%E5%A4%AE%E8%A1%8C
# 外部連結: [虛擬商品] /wiki/%E8%99%9B%E6%93%AC%E5%95%86%E5%93%81
# 外部連結: [挖礦] /wiki/%E6%8C%96%E7%A4%A6_(%E6%AF%94%E7%89%B9%E5%B9%A3)
# 外部連結: [通貨膨脹] /wiki/%E9%80%9A%E8%B2%A8%E8%86%A8%E8%84%B9
# 外部連結: [數位簽章] /wiki/%E6%95%B0%E5%AD%97%E7%AD%BE%E5%90%8D
# 外部連結: [銀行] /wiki/%E9%8A%80%E8%A1%8C
# 外部連結: [證券商] /wiki/%E8%AF%81%E5%88%B8%E5%95%86
# 外部連結: [電子支付] /wiki/%E7%94%B5%E5%AD%90%E6%94%AF%E4%BB%98
# 外部連結: [Steam] /wiki/Steam
# 外部連結: [閃電網路] /wiki/%E9%97%AA%E7%94%B5%E7%BD%91%E7%BB%9C
# 外部連結: [國家主權] /wiki/%E5%9B%BD%E5%AE%B6%E4%B8%BB%E6%9D%83
# 外部連結: [貨幣政策] /wiki/%E8%B2%A8%E5%B9%A3%E6%94%BF%E7%AD%96
# 外部連結: [禮物經濟] /wiki/%E7%A4%BC%E7%89%A9%E7%BB%8F%E6%B5%8E
# 外部連結: [社區共識貨幣自主] /wiki/%E9%A6%96%E6%AC%A1%E4%BB%A3%E5%B8%81%E5%8F%91%E5%94%AE
# 外部連結: [區塊鏈] /wiki/%E5%8C%BA%E5%9D%97%E9%93%BE
# 外部連結: [密碼技術] /wiki/%E5%AF%86%E7%A0%81%E5%AD%A6
# 外部連結: [劍橋大學] /wiki/%E5%89%91%E6%A1%A5%E5%A4%A7%E5%AD%A6
# 外部連結: [等比數列] /wiki/%E7%AD%89%E6%AF%94%E6%95%B8%E5%88%97
# 外部連結: [區塊鏈] /wiki/%E5%8C%BA%E5%9D%97%E9%93%BE
# 外部連結: [分散式資料庫] /wiki/%E5%88%86%E6%95%A3%E5%BC%8F%E8%B3%87%E6%96%99%E5%BA%AB
# 外部連結: [雜湊函式] /wiki/%E6%95%A3%E5%88%97%E5%87%BD%E6%95%B8
# 外部連結: [泰晤士報] /wiki/%E6%B3%B0%E6%99%A4%E5%A3%AB%E5%A0%B1
# 外部連結: [對等網路] /wiki/%E5%B0%8D%E7%AD%89%E7%B6%B2%E8%B7%AF
# 外部連結: [多次發送同一份額] /wiki/%E9%9B%99%E9%87%8D%E6%94%AF%E4%BB%98
# 外部連結: [礦業] /wiki/%E7%A4%A6%E6%A5%AD
# 外部連結: [SHA-256] /wiki/SHA-2
# 外部連結: [RIPEMD-160] /wiki/RIPEMD-160
# 外部連結: [Base58] /wiki/Base58
# 外部連結: [[來源請求]] /wiki/Wikipedia:%E5%88%97%E6%98%8E%E6%9D%A5%E6%BA%90
# 外部連結: [地球] /wiki/%E5%9C%B0%E7%90%83
# 外部連結: [私鑰] /wiki/%E7%A7%81%E9%92%A5
# 外部連結: [金融卡] /wiki/%E9%87%91%E8%9E%8D%E5%8D%A1
# 外部連結: [公鑰] /wiki/%E5%85%AC%E9%92%A5
# 外部連結: [身分證] /wiki/%E8%BA%AB%E5%88%86%E8%AD%89
# 外部連結: [中央處理器] /wiki/%E4%B8%AD%E5%A4%AE%E5%A4%84%E7%90%86%E5%99%A8
# 外部連結: [圖形處理器] /wiki/%E5%9C%96%E5%BD%A2%E8%99%95%E7%90%86%E5%99%A8
# 外部連結: [特殊應用積體電路] /wiki/%E7%89%B9%E6%AE%8A%E6%87%89%E7%94%A8%E7%A9%8D%E9%AB%94%E9%9B%BB%E8%B7%AF
# 外部連結: [礦物] /wiki/%E7%A4%A6%E7%89%A9
# 外部連結: [一幣多付] /wiki/%E4%B8%80%E5%B9%A3%E5%A4%9A%E4%BB%98
# 外部連結: [比特幣無限] /wiki/Bitcoin_Unlimited
# 外部連結: [比特幣現金] /wiki/%E6%AF%94%E7%89%B9%E5%B9%A3%E7%8F%BE%E9%87%91
# 外部連結: [Bitconnect] /wiki/Bitconnect
# 外部連結: [Bitfinex] /wiki/Bitfinex
# 外部連結: [ICO] /wiki/%E9%A6%96%E6%AC%A1%E4%BB%A3%E5%B8%81%E5%8F%91%E8%A1%8C
# 外部連結: [首次代幣發行] /wiki/%E9%A6%96%E6%AC%A1%E4%BB%A3%E5%B8%81%E5%8F%91%E8%A1%8C
# 外部連結: [數位簽章] /wiki/%E6%95%B8%E4%BD%8D%E7%B0%BD%E7%AB%A0
# 外部連結: [絲路] /wiki/%E7%B5%B2%E8%B7%AF_(%E8%B3%BC%E7%89%A9%E7%B6%B2%E7%AB%99)
# 外部連結: [美國司法部] /wiki/%E7%BE%8E%E5%9C%8B%E5%8F%B8%E6%B3%95%E9%83%A8
# 外部連結: [P2P] /wiki/%E5%AF%B9%E7%AD%89%E7%BD%91%E7%BB%9C
# 外部連結: [密碼學] /wiki/%E5%AF%86%E7%A0%81%E5%AD%A6
# 外部連結: [P2P] /wiki/%E5%AF%B9%E7%AD%89%E7%BD%91%E7%BB%9C
# 外部連結: [P2P] /wiki/%E5%AF%B9%E7%AD%89%E7%BD%91%E7%BB%9C
# 外部連結: [P2P] /wiki/%E5%AF%B9%E7%AD%89%E7%BD%91%E7%BB%9C
# 外部連結: [密碼學] /wiki/%E5%AF%86%E7%A0%81%E5%AD%A6
# 外部連結: [貨幣] /wiki/%E8%B4%A7%E5%B8%81
# 外部連結: [交易所] /wiki/%E4%BA%A4%E6%98%93%E6%89%80
# 外部連結: [交易所] /wiki/%E4%BA%A4%E6%98%93%E6%89%80
# 外部連結: [銀行] /wiki/%E9%93%B6%E8%A1%8C
# 外部連結: [洗錢] /wiki/%E6%B4%97%E9%8C%A2
# 外部連結: [達世幣] /wiki/%E9%81%94%E4%B8%96%E5%B9%A3
# 外部連結: [門羅幣] /wiki/%E9%97%A8%E7%BD%97%E5%B8%81
# 外部連結: [Zcash] /wiki/Zcash
# 外部連結: [趨勢科技] /wiki/%E8%B6%A8%E5%8B%A2%E7%A7%91%E6%8A%80
# 外部連結: [澳大利亞廣播公司] /wiki/%E6%BE%B3%E5%A4%A7%E5%88%A9%E4%BA%9A%E5%B9%BF%E6%92%AD%E5%85%AC%E5%8F%B8
# 外部連結: [賽門鐵克] /wiki/%E8%B5%9B%E9%97%A8%E9%93%81%E5%85%8B
# 外部連結: [殭屍網路] /wiki/%E5%83%B5%E5%B0%B8%E7%BD%91%E7%BB%9C
# 外部連結: [顯示卡] /wiki/%E6%98%BE%E5%8D%A1
# 外部連結: [平行計算] /wiki/%E5%B9%B6%E8%A1%8C%E8%AE%A1%E7%AE%97
# 外部連結: [阿根廷] /wiki/%E9%98%BF%E6%A0%B9%E5%BB%B7
# 外部連結: [布宜諾斯艾利斯] /wiki/%E5%B8%83%E5%AE%9C%E8%AB%BE%E6%96%AF%E8%89%BE%E5%88%A9%E6%96%AF
# 外部連結: [星巴克] /wiki/%E6%98%9F%E5%B7%B4%E5%85%8B
# 外部連結: [Wi-Fi] /wiki/Wi-Fi
# 外部連結: [龐氏騙局] /wiki/%E5%BA%9E%E6%B0%8F%E9%AA%97%E5%B1%80
# 外部連結: [絲綢之路] /wiki/%E4%B8%9D%E7%BB%B8%E4%B9%8B%E8%B7%AF_(%E5%8C%BF%E5%90%8D%E5%8C%96%E4%BA%A4%E6%98%93%E5%B8%82%E5%9C%BA)
# 外部連結: [黑市] /wiki/%E9%BB%91%E5%B8%82
# 外部連結: [Amazon.com] /wiki/Amazon.com
# 外部連結: [查爾斯·舒默] /wiki/%E6%9F%A5%E5%85%8B%C2%B7%E8%88%92%E9%BB%98
# 外部連結: [絲綢之路] /wiki/%E4%B8%9D%E7%BB%B8%E4%B9%8B%E8%B7%AF
# 外部連結: [洗錢] /wiki/%E6%B4%97%E9%92%B1
# 外部連結: [TOR] /wiki/TOR
# 外部連結: [絲綢之路] /wiki/%E4%B8%9D%E7%BB%B8%E4%B9%8B%E8%B7%AF
# 外部連結: [美國司法部] /wiki/%E7%BE%8E%E5%9C%8B%E5%8F%B8%E6%B3%95%E9%83%A8
# 外部連結: [查理·史瑞姆] /wiki/%E6%9F%A5%E7%90%86%C2%B7%E5%8F%B2%E7%91%9E%E5%A7%86
# 外部連結: [絲綢之路] /wiki/%E4%B8%9D%E7%BB%B8%E4%B9%8B%E8%B7%AF_(%E5%8C%BF%E5%90%8D%E5%8C%96%E4%BA%A4%E6%98%93%E5%B8%82%E5%9C%BA)
# 外部連結: [黑市] /wiki/%E9%BB%91%E5%B8%82
# 外部連結: [絲路] /wiki/%E7%B5%B2%E8%B7%AF_(%E8%B3%BC%E7%89%A9%E7%B6%B2%E7%AB%99)
# 外部連結: [勒索軟體] /wiki/%E5%8B%92%E7%B4%A2%E8%BB%9F%E9%AB%94
# 外部連結: [WannaCry] /wiki/WannaCry
# 外部連結: [Petya] /wiki/Petya
# 外部連結: [電子貨幣] /wiki/%E7%94%B5%E5%AD%90%E8%B4%A7%E5%B8%81
# 外部連結: [現金] /wiki/%E7%8E%B0%E9%87%91
# 外部連結: [金幣] /wiki/%E9%87%91%E5%B8%81
# 外部連結: [金融卡] /wiki/%E9%87%91%E8%9E%8D%E5%8D%A1
# 外部連結: [維基解密] /wiki/%E7%BB%B4%E5%9F%BA%E8%A7%A3%E5%AF%86
# 外部連結: [金融卡] /wiki/%E9%87%91%E8%9E%8D%E5%8D%A1
# 外部連結: [信用卡] /wiki/%E4%BF%A1%E7%94%A8%E5%8D%A1
# 外部連結: [Apple Pay] /wiki/Apple_Pay
# 外部連結: [行動支付] /wiki/%E8%A1%8C%E5%8B%95%E6%94%AF%E4%BB%98

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
def WikiArticle(key_word_link, key_word, recursive):
    
    if (recursive <= max_recursive_depth):
        print("遞迴層[%d] - %s (%s)" % (recursive, key_word_link, key_word))
        
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': '/wiki/' + key_word_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
        
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
       
        for paragraph in content:  
            file_name = key_word.replace('/', '_')  # 以'_'取代'/', 避免檔名被誤解釋成路徑
            f = open("WikiArticle/" + file_name, "a+", encoding='utf-8')
            f.write( str(paragraph.get_text()) + "\n" )
            f.close()

        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #
        external_link_dict = dict({})
        for ext_link in content:
            a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
            if len(a_tag) > 0:
                for link_string in a_tag:
                    a_link = link_string["href"]       # 外部連結的網址
                    a_keyword = link_string.get_text()  # 外部連結的中文名稱
                    #print("外部連結: %s [%s]" % (a_link, a_keyword))
                    external_link_dict[a_link] = a_keyword

                    
        #
        # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
        #
        if (len(external_link_dict) > 0):
            
            recursive = recursive + 1  # 遞迴深度加1
            
            for k, v in external_link_dict.items():
                WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 3

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E6%AF%94%E7%89%B9%E5%B9%A3 (比特幣)
# 遞迴層[1] - /wiki/%E9%BB%9E%E5%B0%8D%E9%BB%9E (點對點)
# 遞迴層[2] - /wiki/%E5%8E%BB%E4%B8%AD%E5%BF%83%E5%8C%96 (無中心伺服器)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/%E7%A4%BE%E4%BC%9A%E5%85%B3%E7%B3%BB (社會關係)
# 遞迴層[3] - /wiki/Web_2.0 (Web 2.0)
# 遞迴層[3] - /wiki/Flickr (浮利客)
# 遞迴層[3] - /wiki/Blogger (部落格)
# 遞迴層[3] - /wiki/%E6%8E%A8%E7%89%B9 (推特)
# 遞迴層[3] - /wiki/%E8%84%B8%E4%B9%A6 (臉書)
# 遞迴層[3] - /wiki/%E7%BB%B4%E5%9F%BA%E7%99%BE%E7%A7%91 (維基百科)
# 遞迴層[2] - /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB (檔案分享)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/%E5%B1%80%E5%9F%9F%E7%BD%91 (區域網路)
# 遞迴層[3] - /wiki/%E9%9B%BB%E8%85%A6%E6%AA%94%E6%A1%88 (電腦檔案)
# 遞迴層[3] - /wiki/%E5%B0%8D%E7%AD%89%E7%B6%B2%E8%B7%AF (P2P)
# 遞迴層[3] - /wiki/Napster (Napster)
# 遞迴層[3] - /wiki/MP3 (MP3)
# 遞迴層[3] - /wiki/IRC (IRC)
# 遞迴層[3] - /wiki/%E5%8D%B3%E6%99%82%E9%80%9A%E8%A8%8A (即時通訊)
# 遞迴層[3] - /wiki/%E9%80%86%E5%90%91%E5%B7%A5%E7%A8%8B (逆向工程)
# 遞迴層[3] - /wiki/%E5%BC%80%E6%94%BE%E6%BA%90%E4%BB%A3%E7%A0%81 (開放原始碼)
# 遞迴層[3] - /wiki/Gnutella (Gnutella)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9C%8B%E5%94%B1%E7%89%87%E6%A5%AD%E5%8D%94%E6%9C%83 (美國唱片工業協會)
# 遞迴層[3] - /wiki/ITunes (iTunes)
# 遞迴層[3] - /wiki/%E9%97%B4%E8%B0%8D%E8%BD%AF%E4%BB%B6 (間諜軟體)
# 遞迴層[3] - /wiki/%E8%91%97%E4%BD%9C%E6%AC%8A (著作權)
# 遞迴層[3] - /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF (客戶端)
# 遞迴層[3] - /wiki/EMule (eMule)
# 遞迴層[3] - /wiki/%E5%A4%9A%E6%BA%90%E6%96%87%E4%BB%B6%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE (多重來源檔案傳輸協定)
# 遞迴層[3] - /wiki/BitTorrent (BitTorrent協定)
# 遞迴層[3] - /wiki/DCPlusPlus (DC++)
# 遞迴層[3] - /wiki/EDonkey2000 (eDonkey2000)
# 遞迴層[3] - /wiki/EDonkey%E7%BD%91%E7%BB%9C (eDonkey網路)
# 遞迴層[3] - /wiki/Overnet (Overnet)
# 遞迴層[3] - /wiki/Kad%E7%BD%91%E7%BB%9C (Kad網路)
# 遞迴層[3] - /wiki/Nullsoft (Nullsoft)
# 遞迴層[3] - /wiki/Shareaza (Shareaza)
# 遞迴層[3] - /wiki/UDP (UDP)
# 遞迴層[3] - /wiki/WinMX (WinMX)
# 遞迴層[3] - /wiki/Winny (WinNY)
# 遞迴層[2] - /wiki/%E6%AF%94%E7%89%B9%E5%B8%81 (比特幣)
# 遞迴層[3] - /wiki/%E9%BB%9E%E5%B0%8D%E9%BB%9E (點對點)
# 遞迴層[3] - /wiki/%E5%85%B1%E8%AF%86%E4%B8%BB%E5%8A%A8%E6%80%A7 (共識主動性)
# 遞迴層[3] - /wiki/%E9%96%8B%E6%94%BE%E5%8E%9F%E5%A7%8B%E7%A2%BC (開放原始碼)
# 遞迴層[3] - /wiki/%E5%8C%BA%E5%9D%97%E9%93%BE (區塊鏈)
# 遞迴層[3] - /wiki/%E5%8A%A0%E5%AF%86%E8%B2%A8%E5%B9%A3 (加密貨幣)
# 遞迴層[3] - /wiki/%E4%B8%AD%E6%9C%AC%E8%81%AA (中本聰)
# 遞迴層[3] - /wiki/%E5%A4%AE%E8%A1%8C (央行)
# 遞迴層[3] - /wiki/%E8%99%9B%E6%93%AC%E5%95%86%E5%93%81 (虛擬商品)
# 遞迴層[3] - /wiki/%E6%8C%96%E7%A4%A6_(%E6%AF%94%E7%89%B9%E5%B9%A3) (挖礦)
# 遞迴層[3] - /wiki/%E9%80%9A%E8%B2%A8%E8%86%A8%E8%84%B9 (通貨膨脹)
# 遞迴層[3] - /wiki/%E6%95%B0%E5%AD%97%E7%AD%BE%E5%90%8D (數位簽章)
# 遞迴層[3] - /wiki/%E9%8A%80%E8%A1%8C (銀行)
# 遞迴層[3] - /wiki/%E8%AF%81%E5%88%B8%E5%95%86 (證券商)
# 遞迴層[3] - /wiki/%E7%94%B5%E5%AD%90%E6%94%AF%E4%BB%98 (電子支付)
# 遞迴層[3] - /wiki/Steam (Steam)
# 遞迴層[3] - /wiki/%E9%97%AA%E7%94%B5%E7%BD%91%E7%BB%9C (閃電網路)
# 遞迴層[3] - /wiki/%E5%9B%BD%E5%AE%B6%E4%B8%BB%E6%9D%83 (國家主權)
# 遞迴層[3] - /wiki/%E8%B2%A8%E5%B9%A3%E6%94%BF%E7%AD%96 (貨幣政策)
# 遞迴層[3] - /wiki/%E7%A4%BC%E7%89%A9%E7%BB%8F%E6%B5%8E (禮物經濟)
# 遞迴層[3] - /wiki/%E9%A6%96%E6%AC%A1%E4%BB%A3%E5%B8%81%E5%8F%91%E5%94%AE (社區共識貨幣自主)
# 遞迴層[3] - /wiki/%E5%AF%86%E7%A0%81%E5%AD%A6 (密碼學)
# 遞迴層[3] - /wiki/%E5%89%91%E6%A1%A5%E5%A4%A7%E5%AD%A6 (劍橋大學)
# 遞迴層[3] - /wiki/%E7%AD%89%E6%AF%94%E6%95%B8%E5%88%97 (等比數列)
# 遞迴層[3] - /wiki/%E5%88%86%E6%95%A3%E5%BC%8F%E8%B3%87%E6%96%99%E5%BA%AB (分散式資料庫)
# 遞迴層[3] - /wiki/%E6%95%A3%E5%88%97%E5%87%BD%E6%95%B8 (雜湊函式)
# 遞迴層[3] - /wiki/%E6%B3%B0%E6%99%A4%E5%A3%AB%E5%A0%B1 (泰晤士報)
# 遞迴層[3] - /wiki/%E5%B0%8D%E7%AD%89%E7%B6%B2%E8%B7%AF (對等網路)
# 遞迴層[3] - /wiki/%E9%9B%99%E9%87%8D%E6%94%AF%E4%BB%98 (多次發送同一份額)
# 遞迴層[3] - /wiki/%E7%A4%A6%E6%A5%AD (礦業)
# 遞迴層[3] - /wiki/SHA-2 (SHA-256)
# 遞迴層[3] - /wiki/RIPEMD-160 (RIPEMD-160)
# 遞迴層[3] - /wiki/Base58 (Base58)
# 遞迴層[3] - /wiki/Wikipedia:%E5%88%97%E6%98%8E%E6%9D%A5%E6%BA%90 ([來源請求])
# 遞迴層[3] - /wiki/%E5%9C%B0%E7%90%83 (地球)
# 遞迴層[3] - /wiki/%E7%A7%81%E9%92%A5 (私鑰)
# 遞迴層[3] - /wiki/%E9%87%91%E8%9E%8D%E5%8D%A1 (金融卡)
# 遞迴層[3] - /wiki/%E5%85%AC%E9%92%A5 (公鑰)
# 遞迴層[3] - /wiki/%E8%BA%AB%E5%88%86%E8%AD%89 (身分證)
# 遞迴層[3] - /wiki/%E4%B8%AD%E5%A4%AE%E5%A4%84%E7%90%86%E5%99%A8 (中央處理器)
# 遞迴層[3] - /wiki/%E5%9C%96%E5%BD%A2%E8%99%95%E7%90%86%E5%99%A8 (圖形處理器)
# 遞迴層[3] - /wiki/%E7%89%B9%E6%AE%8A%E6%87%89%E7%94%A8%E7%A9%8D%E9%AB%94%E9%9B%BB%E8%B7%AF (特殊應用積體電路)
# 遞迴層[3] - /wiki/%E7%A4%A6%E7%89%A9 (礦物)
# 遞迴層[3] - /wiki/%E4%B8%80%E5%B9%A3%E5%A4%9A%E4%BB%98 (一幣多付)
# 遞迴層[3] - /wiki/Bitcoin_Unlimited (比特幣無限)
# 遞迴層[3] - /wiki/%E6%AF%94%E7%89%B9%E5%B9%A3%E7%8F%BE%E9%87%91 (比特幣現金)
# 遞迴層[3] - /wiki/Bitconnect (Bitconnect)
# 遞迴層[3] - /wiki/Bitfinex (Bitfinex)
# 遞迴層[3] - /wiki/%E9%A6%96%E6%AC%A1%E4%BB%A3%E5%B8%81%E5%8F%91%E8%A1%8C (首次代幣發行)
# 遞迴層[3] - /wiki/%E6%95%B8%E4%BD%8D%E7%B0%BD%E7%AB%A0 (數位簽章)
# 遞迴層[3] - /wiki/%E7%B5%B2%E8%B7%AF_(%E8%B3%BC%E7%89%A9%E7%B6%B2%E7%AB%99) (絲路)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9C%8B%E5%8F%B8%E6%B3%95%E9%83%A8 (美國司法部)
# 遞迴層[3] - /wiki/%E5%AF%B9%E7%AD%89%E7%BD%91%E7%BB%9C (P2P)
# 遞迴層[3] - /wiki/%E8%B4%A7%E5%B8%81 (貨幣)
# 遞迴層[3] - /wiki/%E4%BA%A4%E6%98%93%E6%89%80 (交易所)
# 遞迴層[3] - /wiki/%E9%93%B6%E8%A1%8C (銀行)
# 遞迴層[3] - /wiki/%E6%B4%97%E9%8C%A2 (洗錢)
# 遞迴層[3] - /wiki/%E9%81%94%E4%B8%96%E5%B9%A3 (達世幣)
# 遞迴層[3] - /wiki/%E9%97%A8%E7%BD%97%E5%B8%81 (門羅幣)
# 遞迴層[3] - /wiki/Zcash (Zcash)
# 遞迴層[3] - /wiki/%E8%B6%A8%E5%8B%A2%E7%A7%91%E6%8A%80 (趨勢科技)
# 遞迴層[3] - /wiki/%E6%BE%B3%E5%A4%A7%E5%88%A9%E4%BA%9A%E5%B9%BF%E6%92%AD%E5%85%AC%E5%8F%B8 (澳大利亞廣播公司)
# 遞迴層[3] - /wiki/%E8%B5%9B%E9%97%A8%E9%93%81%E5%85%8B (賽門鐵克)
# 遞迴層[3] - /wiki/%E5%83%B5%E5%B0%B8%E7%BD%91%E7%BB%9C (殭屍網路)
# 遞迴層[3] - /wiki/%E6%98%BE%E5%8D%A1 (顯示卡)
# 遞迴層[3] - /wiki/%E5%B9%B6%E8%A1%8C%E8%AE%A1%E7%AE%97 (平行計算)
# 遞迴層[3] - /wiki/%E9%98%BF%E6%A0%B9%E5%BB%B7 (阿根廷)
# 遞迴層[3] - /wiki/%E5%B8%83%E5%AE%9C%E8%AB%BE%E6%96%AF%E8%89%BE%E5%88%A9%E6%96%AF (布宜諾斯艾利斯)
# 遞迴層[3] - /wiki/%E6%98%9F%E5%B7%B4%E5%85%8B (星巴克)
# 遞迴層[3] - /wiki/Wi-Fi (Wi-Fi)
# 遞迴層[3] - /wiki/%E5%BA%9E%E6%B0%8F%E9%AA%97%E5%B1%80 (龐氏騙局)
# 遞迴層[3] - /wiki/%E4%B8%9D%E7%BB%B8%E4%B9%8B%E8%B7%AF_(%E5%8C%BF%E5%90%8D%E5%8C%96%E4%BA%A4%E6%98%93%E5%B8%82%E5%9C%BA) (絲綢之路)
# 遞迴層[3] - /wiki/%E9%BB%91%E5%B8%82 (黑市)
# 遞迴層[3] - /wiki/Amazon.com (Amazon.com)
# 遞迴層[3] - /wiki/%E6%9F%A5%E5%85%8B%C2%B7%E8%88%92%E9%BB%98 (查爾斯·舒默)
# 遞迴層[3] - /wiki/%E4%B8%9D%E7%BB%B8%E4%B9%8B%E8%B7%AF (絲綢之路)
# 遞迴層[3] - /wiki/%E6%B4%97%E9%92%B1 (洗錢)
# 遞迴層[3] - /wiki/TOR (TOR)
# 遞迴層[3] - /wiki/%E6%9F%A5%E7%90%86%C2%B7%E5%8F%B2%E7%91%9E%E5%A7%86 (查理·史瑞姆)
# 遞迴層[3] - /wiki/%E5%8B%92%E7%B4%A2%E8%BB%9F%E9%AB%94 (勒索軟體)
# 遞迴層[3] - /wiki/WannaCry (WannaCry)
# 遞迴層[3] - /wiki/Petya (Petya)
# 遞迴層[3] - /wiki/%E7%94%B5%E5%AD%90%E8%B4%A7%E5%B8%81 (電子貨幣)
# 遞迴層[3] - /wiki/%E7%8E%B0%E9%87%91 (現金)
# 遞迴層[3] - /wiki/%E9%87%91%E5%B8%81 (金幣)
# 遞迴層[3] - /wiki/%E7%BB%B4%E5%9F%BA%E8%A7%A3%E5%AF%86 (維基解密)
# 遞迴層[3] - /wiki/%E4%BF%A1%E7%94%A8%E5%8D%A1 (信用卡)
# 遞迴層[3] - /wiki/Apple_Pay (Apple Pay)
# 遞迴層[3] - /wiki/%E8%A1%8C%E5%8B%95%E6%94%AF%E4%BB%98 (行動支付)
# 遞迴層[2] - /wiki/Gnutella (Gnutella)
# 遞迴層[3] - /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB (檔案分享)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/Nullsoft (Nullsoft)
# 遞迴層[3] - /wiki/%E6%BA%90%E4%BB%A3%E7%A0%81 (原始碼)
# 遞迴層[3] - /wiki/GNU%E9%80%9A%E7%94%A8%E5%85%AC%E5%85%B1%E8%AE%B8%E5%8F%AF%E8%AF%81 (GNU通用公共許可證)
# 遞迴層[3] - /wiki/Napster (Napster)
# 遞迴層[3] - /wiki/%E4%B8%93%E6%9C%89%E8%BD%AF%E4%BB%B6 (專有)
# 遞迴層[3] - /wiki/%E9%96%89%E6%BA%90%E8%BB%9F%E9%AB%94 (閉源)
# 遞迴層[3] - /wiki/LimeWire (LimeWire)
# 遞迴層[3] - /wiki/GNU (GNU專案)
# 遞迴層[3] - /wiki/Nutella (Nutella)
# 遞迴層[3] - /wiki/%E6%B7%B7%E6%88%90%E8%A9%9E (混成詞)
# 遞迴層[3] - /wiki/Wikipedia:%E5%A4%B1%E6%95%88%E9%93%BE%E6%8E%A5 (永久失效連結)
# 遞迴層[3] - /wiki/Internet_Relay_Chat (IRC)
# 遞迴層[3] - /wiki/HTTP (HTTP)
# 遞迴層[3] - /wiki/SHA-1 (SHA-1)
# 遞迴層[3] - /wiki/UDP (UDP)
# 遞迴層[3] - /wiki/TCP (TCP)
# 遞迴層[3] - /wiki/XML (XML)
# 遞迴層[2] - /wiki/%E8%87%AA%E7%94%B1%E7%BD%91 (自由網)
# 遞迴層[3] - /wiki/%E5%AF%B9%E7%AD%89%E7%BD%91%E7%BB%9C (對等網絡)
# 遞迴層[3] - /wiki/%E8%BD%AF%E4%BB%B6 (軟體)
# 遞迴層[3] - /wiki/Java (Java)
# 遞迴層[3] - /wiki/%E7%A7%8D%E5%AD%90%E6%96%87%E4%BB%B6 (種子文件)
# 遞迴層[3] - /wiki/%E6%B5%B7%E7%9B%9C%E7%81%A3 (海盜灣)
# 遞迴層[3] - /wiki/%E7%BB%B4%E5%9F%BA%E8%A7%A3%E5%AF%86 (維基解密)
# 遞迴層[3] - /wiki/%E7%B5%B2%E8%B7%AF_(%E8%B3%BC%E7%89%A9%E7%B6%B2%E7%AB%99) (絲綢之路)
# 遞迴層[2] - /wiki/Napster (Napster)
# 遞迴層[3] - /wiki/%E8%A5%BF%E6%81%A9%C2%B7%E5%B8%95%E5%85%8B (西恩·帕克)
# 遞迴層[3] - /wiki/%E7%82%B9%E5%AF%B9%E7%82%B9 (點對點)
# 遞迴層[3] - /wiki/%E5%A4%A7%E5%AD%B8%E7%94%9F (大學生)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/MP3 (MP3)
# 遞迴層[3] - /wiki/%E4%BE%B5%E6%AC%8A (侵權)
# 遞迴層[3] - /wiki/Limewire (Limewire)
# 遞迴層[3] - /wiki/Metallica (Metallica)
# 遞迴層[3] - /wiki/%E7%94%B5%E5%8F%B0 (電台)
# 遞迴層[3] - /wiki/%E5%94%B1%E7%89%87%E5%85%AC%E5%8F%B8 (唱片公司)
# 遞迴層[3] - /wiki/%E7%99%BE%E6%80%9D%E4%B9%B0 (百思買)
# 遞迴層[2] - /wiki/IRC (IRC)
# 遞迴層[3] - /wiki/%E5%BA%94%E7%94%A8%E5%B1%82 (應用層)
# 遞迴層[3] - /wiki/%E5%8D%8F%E8%AE%AE (協定)
# 遞迴層[3] - /wiki/SSL (SSL)
# 遞迴層[3] - /wiki/%E8%8A%AC%E5%85%B0 (芬蘭)
# 遞迴層[3] - /wiki/%E5%82%B3%E8%BC%B8%E6%8E%A7%E5%88%B6%E5%8D%94%E5%AE%9A (TCP)
# 遞迴層[3] - /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF/%E6%9C%8D%E5%8A%A1%E5%99%A8%E7%BB%93%E6%9E%84 (客戶端/伺服器結構)
# 遞迴層[3] - /wiki/Freenode (irc.freenode.net)
# 遞迴層[3] - /wiki/ChanServ (ChanServ)
# 遞迴層[2] - /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF-%E6%9C%8D%E5%8A%A1%E5%99%A8 (客戶端-伺服器)
# 遞迴層[3] - /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF (客戶端)
# 遞迴層[3] - /wiki/%E5%9B%BE%E5%BD%A2%E7%94%A8%E6%88%B7%E7%95%8C%E9%9D%A2 (圖形化使用者介面)
# 遞迴層[3] - /wiki/%E5%BA%94%E7%94%A8%E7%A8%8B%E5%BA%8F%E6%9C%8D%E5%8A%A1%E5%99%A8 (應用程式伺服器)
# 遞迴層[3] - /wiki/%E6%96%87%E4%BB%B6%E6%9C%8D%E5%8A%A1%E5%99%A8 (檔案伺服器)
# 遞迴層[3] - /wiki/%E5%9B%A0%E7%89%B9%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/UML (UML)
# 遞迴層[3] - /wiki/%E9%BB%9E%E5%B0%8D%E9%BB%9E%E6%8A%80%E8%A1%93 (對等架構)
# 遞迴層[2] - /wiki/RFC (RFC)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E5%B7%A5%E7%A8%8B%E4%BB%BB%E5%8A%A1%E7%BB%84 (網際網路工程任務組)
# 遞迴層[3] - /wiki/%E5%82%99%E5%BF%98%E9%8C%84 (備忘錄)
# 遞迴層[3] - /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF (網際網路)
# 遞迴層[3] - /wiki/UNIX (UNIX)
# 遞迴層[3] - /wiki/%E7%A4%BE%E7%BE%A4 (社群)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E5%8D%8F%E4%BC%9A (網際網路協會)
# 遞迴層[3] - /wiki/%E8%B4%8A%E5%8A%A9 (贊助)
# 遞迴層[3] - /wiki/%E6%96%AF%E8%92%82%E8%8A%AC%C2%B7%E5%85%8B%E7%BD%97%E5%85%8B (史蒂芬·克羅克)
# 遞迴層[3] - /wiki/ARPANET (ARPANET)
# 遞迴層[3] - /wiki/ARPA%E7%BD%91 (ARPA網)
# 遞迴層[3] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 遞迴層[3] - /wiki/%E5%8A%A0%E5%B7%9E%E5%A4%A7%E5%AD%A6%E6%B4%9B%E6%9D%89%E7%9F%B6%E5%88%86%E6%A0%A1 (加州大學洛杉磯分校)
# 遞迴層[3] - /wiki/%E6%96%AF%E5%9D%A6%E7%A6%8F%E5%A4%A7%E5%AD%A6 (斯坦福研究所)
# 遞迴層[3] - /wiki/%E5%9C%A3%E5%A1%94%E8%8A%AD%E8%8A%AD%E6%8B%89%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9A%E5%A4%A7%E5%AD%A6 (加州大學聖塔芭芭拉分校)
# 遞迴層[3] - /wiki/%E7%8A%B9%E4%BB%96%E5%A4%A7%E5%AD%A6 (猶他大學)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E9%98%B2%E9%83%A8 (美國國防部)
# 遞迴層[3] - /wiki/%E5%AE%A4%E5%8F%8B (室友)
# 遞迴層[3] - /wiki/%E6%B5%B4%E5%AE%A4 (浴室)
# 遞迴層[3] - /wiki/Douglas_Engelbart (Douglas Engelbart)
# 遞迴層[3] - /wiki/%E7%A4%BE%E6%9C%83%E5%AD%B8%E5%AE%B6 (社會學家)
# 遞迴層[3] - /wiki/Jon_Postel (Jon Postel)
# 遞迴層[3] - /wiki/%E7%BC%96%E8%BE%91 (編輯)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD (美國)
# 遞迴層[3] - /wiki/%E6%94%BF%E5%BA%9C (政府)
# 遞迴層[3] - /wiki/%E5%8D%97%E5%8A%A0%E5%B7%9E%E5%A4%A7%E5%AD%A6 (南加州大學)
# 遞迴層[3] - /wiki/%E6%B8%85%E5%8D%8E%E5%A4%A7%E5%AD%A6 (清華大學)
# 遞迴層[3] - /wiki/ASCII (ASCII)
# 遞迴層[3] - /wiki/%E6%83%A1%E6%90%9ERFC (惡搞PFC)
# 遞迴層[3] - /wiki/%E6%84%9A%E4%BA%BA%E7%AF%80 (愚人節)
# 遞迴層[3] - /wiki/IPv9 (IPv9)
# 遞迴層[3] - /wiki/HTCPCP (超文字咖啡壺控制協定)
# 遞迴層[2] - /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8 (伺服器)
# 遞迴層[3] - /wiki/%E7%B6%B2%E7%B5%A1 (網絡)
# 遞迴層[3] - /wiki/Intranet (內部網路)
# 遞迴層[3] - /wiki/Internet (網際網路)
# 遞迴層[3] - /wiki/%E8%B0%83%E5%88%B6%E8%A7%A3%E8%B0%83%E5%99%A8 (數據機)
# 遞迴層[3] - /wiki/%E5%AF%AC%E9%A0%BB (寬頻)
# 遞迴層[3] - /wiki/%E9%9B%B2%E7%AB%AF%E8%A8%88%E7%AE%97 (雲端計算)
# 遞迴層[3] - /wiki/%E5%A4%A7%E6%95%B8%E6%93%9A (巨量資料)
# 遞迴層[3] - /wiki/%E7%B6%B2%E8%B7%AF%E5%95%86%E5%BA%97 (網路商店)
# 遞迴層[3] - /wiki/%E7%B6%B2%E8%B7%AF%E6%8B%8D%E8%B3%A3 (網路拍賣)
# 遞迴層[3] - /wiki/%E7%B6%B2%E8%B7%AF%E9%81%8A%E6%88%B2 (網路遊戲)
# 遞迴層[3] - /wiki/%E7%B6%B2%E7%AB%99 (網站)
# 遞迴層[3] - /wiki/%E7%B6%B2%E8%AA%8C (部落格)
# 遞迴層[3] - /wiki/NAS (NAS)
# 遞迴層[3] - /wiki/%E7%BD%91%E9%A1%B5%E6%9C%8D%E5%8A%A1%E5%99%A8 (網頁伺服器)
# 遞迴層[3] - /wiki/%E7%BD%91%E7%AB%99 (網站)
# 遞迴層[3] - /wiki/Apache (Apache)
# 遞迴層[3] - /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 (網頁瀏覽器)
# 遞迴層[3] - /wiki/%E4%B8%AD%E5%A4%AE%E5%A4%84%E7%90%86%E5%99%A8 (中央處理器)
# 遞迴層[3] - /wiki/%E7%A1%AC%E7%9B%98 (硬碟)
# 遞迴層[3] - /wiki/%E5%86%85%E5%AD%98 (記憶體)
# 遞迴層[3] - /wiki/%E7%A1%AC%E4%BB%B6 (硬體)
# 遞迴層[3] - /wiki/PC (PC)
# 遞迴層[3] - /wiki/%E7%B5%82%E7%AB%AF (終端)
# 遞迴層[3] - /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF (客戶端)
# 遞迴層[3] - /wiki/%E5%80%8B%E4%BA%BA%E9%9B%BB%E8%85%A6 (個人電腦)
# 遞迴層[3] - /wiki/%E5%8F%AF%E9%9D%A0%E6%80%A7%E3%80%81%E5%8F%AF%E7%94%A8%E6%80%A7%E5%92%8C%E5%8F%AF%E7%B6%AD%E8%AD%B7%E6%80%A7 (RAS)
# 遞迴層[3] - /wiki/%E7%BA%A0%E9%94%99%E5%86%85%E5%AD%98 (ECC記憶體)
# 遞迴層[3] - /wiki/%E6%93%8D%E4%BD%9C%E7%B3%BB%E7%BB%9F (作業系統)
# 遞迴層[3] - /wiki/%E7%B1%BBUnix (類Unix)
# 遞迴層[3] - /wiki/Unix (Unix)
# 遞迴層[3] - /wiki/Linux%E5%8F%91%E8%A1%8C%E7%89%88 (Linux發行版)
# 遞迴層[3] - /wiki/Red_Hat_Enterprise_Linux (紅帽企業Linux)
# 遞迴層[3] - /wiki/SUSE (SUSE)
# 遞迴層[3] - /wiki/AIX (AIX)
# 遞迴層[3] - /wiki/IRIX (IRIX)
# 遞迴層[3] - /wiki/Solaris (Solaris)
# 遞迴層[3] - /wiki/BSD (BSD)
# 遞迴層[3] - /wiki/OpenBSD (OpenBSD)
# 遞迴層[3] - /wiki/NetBSD (NetBSD)
# 遞迴層[3] - /wiki/%E5%BE%AE%E8%BD%AF (微軟)
# 遞迴層[3] - /wiki/Windows_Server (Windows Server)
# 遞迴層[3] - /wiki/Windows_NT_4.0 (Windows NT 4.0 Server)
# 遞迴層[3] - /wiki/Windows_2000_Server (Windows 2000 Server)
# 遞迴層[3] - /wiki/Windows_Server_2003 (Windows Server 2003)
# 遞迴層[3] - /wiki/Windows_Server_2008 (Windows Server 2008)
# 遞迴層[3] - /wiki/Windows_Server_2008_R2 (Windows Server 2008 R2)
# 遞迴層[3] - /wiki/Windows_Server_2012 (Windows Server 2012)
# 遞迴層[3] - /wiki/Windows_Server_2012_R2 (Windows Server 2012 R2)
# 遞迴層[3] - /wiki/Windows_Server_2016 (Windows Server 2016)
# 遞迴層[3] - /wiki/Windows_Server_2019 (Windows Server 2019)
# 遞迴層[3] - /wiki/%E8%BD%AF%E4%BB%B6 (軟體)
# 遞迴層[3] - /wiki/%E5%AE%A2%E6%88%B7%E7%AB%AF-%E6%9C%8D%E5%8A%A1%E5%99%A8 (客戶端-伺服器)
# 遞迴層[3] - /wiki/%E6%B5%8F%E8%A7%88%E5%99%A8-%E6%9C%8D%E5%8A%A1%E5%99%A8 (瀏覽器-伺服器)
# 遞迴層[3] - /wiki/%E5%88%80%E9%8B%92%E4%BC%BA%E6%9C%8D%E5%99%A8 (刀鋒伺服器)
# 遞迴層[3] - /wiki/%E9%A7%AD%E5%AE%A2 (駭客)
# 遞迴層[3] - /wiki/%E9%98%B2%E7%81%AB%E5%A2%99 (防火牆)
# 遞迴層[3] - /wiki/%E6%BC%8F%E6%B4%9E (漏洞)
# 遞迴層[3] - /wiki/%E6%9B%B4%E6%96%B0 (更新)
# 遞迴層[2] - /wiki/%E5%B8%A6%E5%AE%BD (頻寬)
# 遞迴層[3] - /wiki/%E4%BF%A1%E5%8F%B7 (訊號)
# 遞迴層[3] - /wiki/%E9%A2%91%E5%B8%A6 (頻帶)
# 遞迴層[3] - /wiki/%E4%BF%A1%E9%81%93 (通道)
# 遞迴層[3] - /wiki/%E6%A8%A1%E6%93%AC%E4%BF%A1%E8%99%9F (類比訊號)
# 遞迴層[3] - /wiki/%E8%B5%AB%E5%85%B9 (赫茲)
# 遞迴層[3] - /wiki/%E6%95%B0%E5%AD%97%E4%BF%A1%E5%8F%B7 (數位訊號)
# 遞迴層[3] - /wiki/%E7%B6%9C%E5%90%88%E6%A5%AD%E5%8B%99%E6%95%B8%E5%AD%97%E7%B6%B2 (ISDN)
# 遞迴層[3] - /wiki/%E6%B3%A2%E7%89%B9%E7%8E%87 (波特率)
# 遞迴層[3] - /wiki/%E4%BF%A1%E6%81%AF%E8%AE%BA (資訊理論)
# 遞迴層[3] - /wiki/%E6%97%A0%E7%BA%BF%E7%94%B5 (無線電)
# 遞迴層[3] - /wiki/%E9%80%9A%E4%BF%A1 (通訊)
# 遞迴層[3] - /wiki/%E4%BF%A1%E5%8F%B7%E5%A4%84%E7%90%86 (訊號處理)
# 遞迴層[3] - /wiki/%E6%B3%A2%E8%B0%B1%E5%AD%A6 (波譜學)
# 遞迴層[3] - /wiki/%E8%B0%83%E5%88%B6 (調變)
# 遞迴層[3] - /wiki/%E8%BD%BD%E6%B3%A2 (載波)
# 遞迴層[3] - /wiki/%E5%85%89%E5%AD%A6 (光學)
# 遞迴層[3] - /wiki/%E8%B0%B1%E7%BA%BF (譜線)
# 遞迴層[3] - /wiki/%E9%A2%91%E8%B0%B1 (頻譜)
# 遞迴層[3] - /wiki/%E5%88%86%E8%B2%9D (dB)
# 遞迴層[3] - /wiki/Shannon-Hartley_%E5%AE%9A%E7%90%86 (Shannon-Hartley 定理)
# 遞迴層[3] - /wiki/%E5%82%85%E9%87%8C%E5%8F%B6%E5%8F%98%E6%8D%A2 (傅立葉變換)
# 遞迴層[3] - /wiki/%E4%BC%A0%E9%80%92%E5%87%BD%E6%95%B0 (傳遞函式)
# 遞迴層[3] - /wiki/%E5%AE%9E%E6%95%B0 (實數)
# 遞迴層[3] - /wiki/%E5%9F%BA%E5%B8%A6 (基頻)
# 遞迴層[3] - /wiki/%E4%BD%8E%E9%80%9A%E6%BB%A4%E6%B3%A2%E5%99%A8 (低通濾波器)
# 遞迴層[3] - /wiki/%E7%94%B5%E5%AD%90%E6%BB%A4%E6%B3%A2%E5%99%A8 (電子濾波器)
# 遞迴層[3] - /wiki/%E4%B8%AD%E5%BF%83%E9%A2%91%E7%8E%87 (中心頻率)
# 遞迴層[3] - /wiki/%E6%8E%A7%E5%88%B6%E7%90%86%E8%AE%BA (控制理論)
# 遞迴層[3] - /wiki/%E9%A0%BB%E9%81%93%E5%AE%B9%E9%87%8F (通道容量)
# 遞迴層[3] - /wiki/%E6%95%B8%E5%AD%97 (數字)
# 遞迴層[3] - /wiki/%E7%B8%BD%E7%B7%9A (匯流排)
# 遞迴層[3] - /wiki/%E6%95%B8%E6%93%9A%E6%A9%9F (數據機)
# 遞迴層[3] - /wiki/%E9%9B%BB%E8%A9%B1%E7%B7%9A (電話線)
# 遞迴層[3] - /wiki/%E6%95%B8%E4%BD%8D%E8%A8%8A%E8%99%9F%E8%99%95%E7%90%86 (數位訊號處理)
# 遞迴層[3] - /wiki/%E6%8E%A1%E6%A8%A3%E5%AE%9A%E7%90%86 (Nyquist-Shannon 採樣定理)
# 遞迴層[3] - /wiki/%E6%8E%A1%E6%A8%A3%E7%8E%87 (採樣率)
# 遞迴層[2] - /wiki/%E5%8D%8F%E8%AE%AE (協定)
# 遞迴層[2] - /wiki/%E5%8A%A0%E5%AF%86%E8%B2%A8%E5%B9%A3 (加密貨幣)
# 遞迴層[3] - /wiki/%E5%AF%86%E7%A2%BC%E5%AD%B8 (密碼學)
# 遞迴層[3] - /wiki/%E4%BA%A4%E6%98%93%E5%AA%92%E4%BB%8B (交易媒介)
# 遞迴層[3] - /wiki/%E6%95%B8%E4%BD%8D%E8%B2%A8%E5%B9%A3 (數字貨幣)
# 遞迴層[3] - /wiki/%E8%99%9A%E6%8B%9F%E8%B4%A7%E5%B8%81 (虛擬貨幣)
# 遞迴層[3] - /wiki/%E6%AF%94%E7%89%B9%E5%B8%81 (比特幣)
# 遞迴層[3] - /wiki/%E5%8E%BB%E4%B8%AD%E5%BF%83%E5%8C%96 (去中心化)
# 遞迴層[3] - /wiki/%E5%88%86%E6%95%A3%E5%BC%8F%E8%B3%AC%E6%9C%AC (分散式賬本)
# 遞迴層[3] - /wiki/%E5%8C%BA%E5%9D%97%E9%93%BE (區塊鏈)
# 遞迴層[3] - /wiki/%E9%9F%A6%E6%B0%8F%E8%AF%8D%E5%85%B8 (韋氏詞典)
# 遞迴層[3] - /wiki/%E8%81%94%E9%82%A6%E5%82%A8%E5%A4%87%E7%B3%BB%E7%BB%9F (聯邦儲備系統)
# 遞迴層[3] - /wiki/%E6%B3%95%E5%AE%9A%E8%B2%A8%E5%B9%A3 (法定貨幣)
# 遞迴層[3] - /wiki/%E4%B8%AD%E6%9C%AC%E8%81%AA (中本聰)
# 遞迴層[3] - /wiki/%E6%99%82%E9%96%93%E6%88%B3 (時間戳)
# 遞迴層[3] - /wiki/%E7%8F%BE%E9%87%91 (現金)
# 遞迴層[3] - /wiki/%E6%99%BA%E8%83%BD%E5%90%88%E7%BA%A6 (智慧型合約)
# 遞迴層[3] - /wiki/%E4%BB%A5%E5%A4%AA%E5%9D%8A (以太坊)
# 遞迴層[3] - /wiki/%E8%B4%B5%E9%87%91%E5%B1%9E (貴金屬)
# 遞迴層[3] - /wiki/%E4%B8%AD%E5%9C%8B (中國)
# 遞迴層[3] - /wiki/%E7%91%9E%E5%85%B8 (瑞典)
# 遞迴層[3] - /wiki/%E8%8B%B1%E5%9B%BD (英國)
# 遞迴層[3] - /wiki/%E6%96%B0%E5%8A%A0%E5%9D%A1 (新加坡)
# 遞迴層[3] - /wiki/%E4%B8%AD%E5%A4%AE%E9%93%B6%E8%A1%8C (中央銀行)
# 遞迴層[2] - /wiki/%E6%AF%94%E7%89%B9%E5%B9%A3%E6%AD%B7%E5%8F%B2 (比特幣)
# 遞迴層[3] - /wiki/%E6%AF%94%E7%89%B9%E5%B9%A3 (比特幣)
# 遞迴層[3] - /wiki/%E5%8A%A0%E5%AF%86%E9%9B%BB%E5%AD%90%E8%B2%A8%E5%B9%A3 (加密電子貨幣)
# 遞迴層[3] - /wiki/%E5%AF%86%E7%A2%BC%E5%AD%B8 (密碼學)
# 遞迴層[3] - /wiki/%E6%9D%83%E5%8A%9B%E5%88%86%E6%95%A3 (非依賴特定的中央機構)
# 遞迴層[3] - /wiki/%E4%B8%AD%E6%9C%AC%E8%81%B0 (中本聰)
# 遞迴層[3] - /wiki/%E8%B5%9B%E5%8D%9A%E6%9C%8B%E5%85%8B (數位龐克)
# 遞迴層[3] - /wiki/%E6%95%B8%E4%BD%8D%E8%B2%A8%E5%B9%A3 (數位貨幣)
# 遞迴層[3] - /wiki/%E5%B0%BC%E5%85%8B%C2%B7%E8%96%A9%E5%8D%9A (尼克·薩博)
# 遞迴層[3] - /wiki/%E5%93%88%E7%88%BE%C2%B7%E8%8A%AC%E5%B0%BC (哈爾·芬尼)
# 遞迴層[3] - /wiki/%E5%8F%AF%E4%BF%A1%E5%B9%B3%E5%8F%B0%E6%A8%A1%E5%9D%97 (可信平台模塊)
# 遞迴層[3] - /wiki/%E9%80%9A%E8%84%B9 (通脹)
# 遞迴層[3] - /wiki/%E6%8B%9C%E5%8D%A0%E5%BA%AD%E5%B0%86%E5%86%9B%E9%97%AE%E9%A2%98 (拜占庭將軍問題)
# 遞迴層[3] - /wiki/%E5%B0%8D%E7%AD%89%E7%B6%B2%E8%B7%AF (對等網路)
# 遞迴層[3] - /wiki/%E5%BC%80%E6%BA%90%E8%BD%AF%E4%BB%B6 (開源)
# 遞迴層[3] - /wiki/%E6%8A%AB%E8%96%A9 (披薩)
# 遞迴層[3] - /wiki/%E7%B6%AD%E5%9F%BA%E8%A7%A3%E5%AF%86 (維基解密)
# 遞迴層[3] - /wiki/%E7%94%B5%E5%AD%90%E5%89%8D%E5%93%A8%E5%9F%BA%E9%87%91%E4%BC%9A (電子前哨基金會)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9C%8B%E5%B0%88%E5%88%A9%E5%8F%8A%E5%95%86%E6%A8%99%E5%B1%80 (美國專利及商標局)
# 遞迴層[3] - /wiki/%E7%8E%B0%E6%9C%89%E6%8A%80%E6%9C%AF (現有技術)
# 遞迴層[3] - /wiki/%E6%AD%90%E6%B4%B2%E4%B8%BB%E6%AC%8A%E5%82%B5%E5%8B%99%E5%8D%B1%E6%A9%9F (歐洲主權債務危機)
# 遞迴層[2] - /wiki/%E4%BB%A5%E5%A4%AA%E5%9D%8A (以太坊)
# 遞迴層[3] - /wiki/%E5%BC%80%E6%BA%90 (開源)
# 遞迴層[3] - /wiki/%E6%99%BA%E8%83%BD%E5%90%88%E7%BA%A6 (智慧型合約)
# 遞迴層[3] - /wiki/%E5%8C%BA%E5%9D%97%E9%93%BE (區塊鏈)
# 遞迴層[3] - /wiki/%E5%8A%A0%E5%AF%86%E8%B4%A7%E5%B8%81 (加密貨幣)
# 遞迴層[3] - /wiki/%E4%BB%A5%E5%A4%AA%E5%B8%81 (以太幣)
# 遞迴層[3] - /wiki/%E5%8E%BB%E4%B8%AD%E5%BF%83%E5%8C%96 (去中心化)
# 遞迴層[3] - /wiki/%E8%99%9A%E6%8B%9F%E6%9C%BA (虛擬機器)
# 遞迴層[3] - /wiki/%E7%82%B9%E5%AF%B9%E7%82%B9 (對等)
# 遞迴層[3] - /wiki/%E7%B6%AD%E5%A1%94%E5%88%A9%E5%85%8B%C2%B7%E5%B8%83%E7%89%B9%E6%9E%97 (維塔利克·布特林)
# 遞迴層[3] - /wiki/%E9%A6%96%E6%AC%A1%E4%BB%A3%E5%B8%81%E5%8F%91%E5%94%AE (ICO眾籌)
# 遞迴層[3] - /wiki/%E6%AF%94%E7%89%B9%E5%B8%81 (比特幣)
# 遞迴層[3] - /wiki/%E5%B7%A5%E4%BD%9C%E9%87%8F%E8%AD%89%E6%98%8E (工作量證明)
# 遞迴層[3] - /wiki/%E6%9D%83%E7%9B%8A%E8%AF%81%E6%98%8E (權益證明)
# 遞迴層[3] - /wiki/%E6%8C%96%E7%A4%A6 (挖礦)
# 遞迴層[3] - /wiki/%E9%87%8D%E6%94%BE%E6%94%BB%E5%87%BB (重放攻擊)
# 遞迴層[3] - /wiki/%E6%AF%94%E7%89%B9%E5%B8%81%E6%A0%B8%E5%BF%83 (比特幣核心)
# 遞迴層[3] - /wiki/%E6%8C%81%E6%9C%89%E9%87%8F%E8%AD%89%E6%98%8E (權益證明 (PoS))
# 遞迴層[3] - /wiki/%E5%85%B1%E8%AD%98%E6%A9%9F%E5%88%B6 (共識機制演算法)
# 遞迴層[3] - /wiki/%E5%A4%96%E5%8C%AF%E5%B8%82%E5%A0%B4 (外匯市場)
# 遞迴層[3] - /wiki/%E6%99%BA%E6%85%A7%E5%90%88%E7%B4%84 (智慧型合約)
# 遞迴層[3] - /wiki/%E7%B4%90%E7%B4%84%E6%99%82%E5%A0%B1 (紐約時報)
# 遞迴層[3] - /wiki/%E7%B6%93%E6%BF%9F%E5%AD%B8%E4%BA%BA (經濟學人)
# 遞迴層[3] - /wiki/%E6%BC%8F%E6%B4%9E (漏洞)
# 遞迴層[3] - /wiki/%E5%BE%AE%E8%BB%9F%E7%A0%94%E7%A9%B6%E9%99%A2 (微軟研究院)
# 遞迴層[3] - /wiki/Python (Python)
# 遞迴層[3] - /wiki/%E5%AD%97%E8%8A%82%E7%A0%81 (位元組碼)
# 遞迴層[3] - /wiki/%E7%89%A9%E8%81%94%E7%BD%91 (物聯網)
# 遞迴層[3] - /wiki/%E6%99%BA%E6%85%A7%E9%9B%BB%E7%B6%B2 (智慧型電網)
# 遞迴層[3] - /wiki/%E4%BD%93%E8%82%B2%E8%B5%8C%E5%8D%9A (體育賭博)
# 遞迴層[3] - /wiki/%E5%BE%AE%E8%BB%9F (微軟)
# 遞迴層[3] - /wiki/IBM (IBM)
# 遞迴層[3] - /wiki/%E6%91%A9%E6%A0%B9%E5%A4%A7%E9%80%9A (摩根大通)
# 遞迴層[3] - /wiki/Microsoft_Azure (Microsoft Azure)
# 遞迴層[3] - /wiki/%E7%9B%A7%E6%A3%AE%E5%A0%A1%E4%BA%A4%E6%98%93%E6%89%80 (盧森堡交易所)
# 遞迴層[3] - /wiki/%E6%95%B8%E4%BD%8D%E7%B0%BD%E7%AB%A0 (數位簽章)
# 遞迴層[3] - /wiki/%E6%96%B0%E5%8A%A0%E5%9D%A1%E9%87%91%E8%9E%8D%E7%AE%A1%E7%90%86%E5%B1%80 (新加坡金融管理局)
# 遞迴層[3] - /wiki/%E6%96%B0%E5%8A%A0%E5%9D%A1%E5%85%83 (新加坡元)
# 遞迴層[3] - /wiki/%E5%9E%83%E5%9C%BE%E8%A8%8A%E6%81%AF (垃圾訊息)
# 遞迴層[3] - /wiki/%E9%98%BB%E6%96%B7%E6%9C%8D%E5%8B%99%E6%94%BB%E6%93%8A (阻斷服務攻擊)
# 遞迴層[3] - /wiki/%E5%8D%80%E5%A1%8A%E9%8D%8A (區塊鏈)
# 遞迴層[3] - /wiki/%E5%8C%97%E5%A4%A7%E5%B2%B3%E6%98%95%E4%BA%8B%E4%BB%B6 (北大岳昕事件)
# 遞迴層[2] - /wiki/%E5%AE%BE%E8%A5%BF%E6%B3%95%E5%B0%BC%E4%BA%9A%E5%B7%9E%E7%AB%8B%E5%A4%A7%E5%AD%A6 (賓夕法尼亞州立大學)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD (美國)
# 遞迴層[3] - /wiki/%E5%AE%BE%E5%A4%95%E6%B3%95%E5%B0%BC%E4%BA%9A%E5%B7%9E (賓夕法尼亞州)
# 遞迴層[3] - /wiki/%E5%8D%B0%E7%AC%AC%E5%AE%89%E4%BA%BA (印第安人)
# 遞迴層[3] - /wiki/%E5%8C%B9%E5%85%B9%E5%A0%A1 (匹茲堡)
# 遞迴層[3] - /wiki/%E8%B4%B9%E5%9F%8E (費城)
# 遞迴層[3] - /wiki/%E5%B7%A5%E4%B8%9A%E5%B7%A5%E7%A8%8B (工業工程)
# 遞迴層[3] - /wiki/%E6%98%9F%E8%B1%A1%E5%84%80 (星象儀)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD%E8%83%BD%E6%BA%90%E9%83%A8 (美國能源部)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E9%98%B2%E9%83%A8 (美國國防部)
# 遞迴層[3] - /wiki/%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E5%9F%BA%E9%87%91%E4%BC%9A (國家科學基金會)
# 遞迴層[3] - /wiki/%E7%BE%8E%E5%9B%BD%E5%A4%A7%E5%AD%A6%E5%8D%8F%E4%BC%9A (美國大學協會)
# 遞迴層[3] - /wiki/%E5%AE%BE%E5%A4%95%E6%B3%95%E5%B0%BC%E4%BA%9A%E5%B7%9E%E7%AB%8B%E5%A4%A7%E5%AD%A6%E5%B0%BC%E5%A1%94%E5%B0%BC%E9%9B%84%E7%8B%AE%E9%98%9F (賓夕法尼亞州立大學尼塔尼雄獅隊)
# 遞迴層[3] - /wiki/%E5%8C%B9%E5%85%B9%E5%A0%A1%E5%A4%A7%E5%AD%A6 (匹茲堡大學)
# 遞迴層[3] - /wiki/%E5%AE%BE%E5%A4%95%E6%B3%95%E5%B0%BC%E4%BA%9A%E5%A4%A7%E5%AD%A6 (賓夕法尼亞大學)
# 遞迴層[3] - /wiki/%E5%BA%B7%E5%A5%88%E5%B0%94%E5%A4%A7%E5%AD%A6 (康奈爾大學)
# 遞迴層[3] - /wiki/%E5%AF%86%E6%AD%87%E6%A0%B9%E5%A4%A7%E5%AD%A6 (密西根大學)
# 遞迴層[3] - /wiki/%E5%AF%86%E6%AD%87%E6%A0%B9%E5%B7%9E%E7%AB%8B%E5%A4%A7%E5%AD%A6 (密西根州立大學)
# 遞迴層[3] - /wiki/%E4%BF%84%E4%BA%A5%E4%BF%84%E5%B7%9E%E7%AB%8B%E5%A4%A7%E5%AD%A6 (俄亥俄州立大學)
# 遞迴層[3] - /wiki/%E5%86%85%E5%B8%83%E6%8B%89%E6%96%AF%E5%8A%A0%E5%A4%A7%E5%AD%A6 (內布拉斯加大學)
# 遞迴層[3] - /wiki/%E9%98%BF%E6%8B%89%E5%B7%B4%E9%A9%AC%E5%A4%A7%E5%AD%A6 (阿拉巴馬大學)
